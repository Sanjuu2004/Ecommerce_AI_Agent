# %%
pip install fastapi
# Out:
# Collecting fastapi
#   Downloading fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# Collecting starlette<0.48.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.47.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from fastapi) (4.12.2)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.8.0)
# Requirement already satisfied: idna>=2.8 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.1)
# Downloading fastapi-0.116.1-py3-none-any.whl (95 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/2.0 MB 1.1 MB/s eta 0:00:02
#    --------------------- ------------------ 1.0/2.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.2 MB/s eta 0:00:00
# Downloading starlette-0.47.2-py3-none-any.whl (72 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, annotated-types, starlette, pydantic, fastapi
#
#    ---------------------------------------- 0/6 [typing-inspection]
#    ------ --------------------------------- 1/6 [pydantic-core]
#    ------------- -------------------------- 2/6 [annotated-types]
#    -------------------- ------------------- 3/6 [starlette]
#    -------------------- ------------------- 3/6 [starlette]
#    -------------------- ------------------- 3/6 [starlette]
#    -------------------- ------------------- 3/6 [starlette]
#    -------------------- ------------------- 3/6 [starlette]
#    -------------------- ------------------- 3/6 [starlette]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    -------------------------- ------------- 4/6 [pydantic]
#    --------------------------------- ------ 5/6 [fastapi]
#    --------------------------------- ------ 5/6 [fastapi]
#    --------------------------------- ------ 5/6 [fastapi]
#    --------------------------------- ------ 5/6 [fastapi]
#    --------------------------------- ------ 5/6 [fastapi]
#    --------------------------------- ------ 5/6 [fastapi]
#    --------------------------------- ------ 5/6 [fastapi]
#    --------------------------------- ------ 5/6 [fastapi]
#    --------------------------------- ------ 5/6 [fastapi]
#    ---------------------------------------- 6/6 [fastapi]
#
# Successfully installed annotated-types-0.7.0 fastapi-0.116.1 pydantic-2.11.7 pydantic-core-2.33.2 starlette-0.47.2 typing-inspection-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install uvicorn
# Out:
# Collecting uvicorn
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: click>=7.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from uvicorn) (8.1.8)
# Requirement already satisfied: h11>=0.8 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: colorama in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Installing collected packages: uvicorn
# Successfully installed uvicorn-0.35.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.2.3-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.12.2)
# Downloading sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 1.0 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.1 MB 1.0 MB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 1.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 795.5 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.8/2.1 MB 934.5 kB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 998.6 kB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 960.0 kB/s eta 0:00:00
# Downloading greenlet-3.2.3-cp313-cp313-win_amd64.whl (297 kB)
# Installing collected packages: greenlet, sqlalchemy
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    ---------------------------------------- 2/2 [sqlalchemy]
#
# Successfully installed greenlet-3.2.3 sqlalchemy-2.0.41
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install llama-cpp-python
# Out:
# Collecting llama-cpp-python
#   Downloading llama_cpp_python-0.3.14.tar.gz (51.0 MB)
#      ---------------------------------------- 0.0/51.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/51.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/51.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/51.0 MB ? eta -:--:--
#      ---------------------------------------- 0.3/51.0 MB ? eta -:--:--
#      ---------------------------------------- 0.5/51.0 MB 1.0 MB/s eta 0:00:49
#       --------------------------------------- 0.8/51.0 MB 1.1 MB/s eta 0:00:45
#       --------------------------------------- 1.0/51.0 MB 1.2 MB/s eta 0:00:43
#      - -------------------------------------- 1.3/51.0 MB 1.2 MB/s eta 0:00:43
#      - -------------------------------------- 1.6/51.0 MB 1.2 MB/s eta 0:00:43
#      - -------------------------------------- 1.8/51.0 MB 1.2 MB/s eta 0:00:42
#      - -------------------------------------- 2.1/51.0 MB 1.2 MB/s eta 0:00:41
#      - -------------------------------------- 2.4/51.0 MB 1.2 MB/s eta 0:00:42
#      -- ------------------------------------- 2.6/51.0 MB 1.2 MB/s eta 0:00:41
#      -- ------------------------------------- 2.9/51.0 MB 1.2 MB/s eta 0:00:42
6 MB/s eta 0:00:04
#      ----------------------------------- ---- 45.4/51.0 MB 1.6 MB/s eta 0:00:04
#      ----------------------------------- ---- 45.9/51.0 MB 1.6 MB/s eta 0:00:04
#      ------------------------------------ --- 46.1/51.0 MB 1.6 MB/s eta 0:00:04
#      ------------------------------------ --- 46.7/51.0 MB 1.6 MB/s eta 0:00:03
#      ------------------------------------ --- 46.9/51.0 MB 1.6 MB/s eta 0:00:03
#      ------------------------------------- -- 47.4/51.0 MB 1.6 MB/s eta 0:00:03
#      ------------------------------------- -- 48.0/51.0 MB 1.6 MB/s eta 0:00:02
#      ------------------------------------- -- 48.2/51.0 MB 1.6 MB/s eta 0:00:02
#      -------------------------------------- - 48.8/51.0 MB 1.6 MB/s eta 0:00:02
#      -------------------------------------- - 49.3/51.0 MB 1.6 MB/s eta 0:00:02
#      -------------------------------------- - 49.5/51.0 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  50.1/51.0 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  50.3/51.0 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  50.6/51.0 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  50.9/51.0 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  50.9/51.0 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 51.0/51.0 MB 1.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: still running...
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from llama-cpp-python) (4.12.2)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from llama-cpp-python) (2.2.1)
# Collecting diskcache>=5.6.1 (from llama-cpp-python)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jinja2>=2.11.3 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from llama-cpp-python) (3.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from jinja2>=2.11.3->llama-cpp-python) (3.0.2)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
# Building wheels for collected packages: llama-cpp-python
#   Building wheel for llama-cpp-python (pyproject.toml): started
#   Building wheel for llama-cpp-python (pyproject.toml): finished with status 'error'
# Failed to build llama-cpp-python
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for llama-cpp-python (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [19 lines of output]
#       *** scikit-build-core 0.11.5 using CMake 4.0.3 (wheel)
#       *** Configuring CMake...
#       loading initial cache file C:\Users\sanju\AppData\Local\Temp\tmp_73m8pp0\build\CMakeInit.txt
#       -- Building for: NMake Makefiles
#       CMake Error at CMakeLists.txt:3 (project):
#         Running
#
#          'nmake' '-?'
#
#         failed with:
#
#          no such file or directory
#
#
#       CMake Error: CMAKE_C_COMPILER not set, after EnableLanguage
#       CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#       -- Configuring incomplete, errors occurred!
#
#       *** CMake configuration failed
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for llama-cpp-python
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (llama-cpp-python)

# %%
pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.3.26-py3-none-any.whl.metadata (7.8 kB)
# Collecting langchain-core<1.0.0,>=0.3.66 (from langchain)
#   Downloading langchain_core-0.3.69-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith>=0.1.17 (from langchain)
#   Downloading langsmith-0.4.8-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.66->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.12.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet>=1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith>=0.1.17->langchain)
#   Downloading orjson-3.11.0-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith>=0.1.17->langchain)
#   Downloading zstandard-0.23.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: anyio in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Downloading langchain-0.3.26-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 288.6 kB/s eta 0:00:02
#    -------------------- ------------------- 0.5/1.0 MB 288.6 kB/s eta 0:00:02
#    -------------------- ------------------- 0.5/1.0 MB 288.6 kB/s eta 0:00:02
#    -------------------- ------------------- 0.5/1.0 MB 288.6 kB/s eta 0:00:02
#    -------------------- ------------------- 0.5/1.0 MB 288.6 kB/s eta 0:00:02
#    -------------------- ------------------- 0.5/1.0 MB 288.6 kB/s eta 0:00:02
#    -------------------- ------------------- 0.5/1.0 MB 288.6 kB/s eta 0:00:02
#    ------------------------------- -------- 0.8/1.0 MB 209.0 kB/s eta 0:00:02
#    ------------------------------- -------- 0.8/1.0 MB 209.0 kB/s eta 0:00:02
#    ------------------------------- -------- 0.8/1.0 MB 209.0 kB/s eta 0:00:02
#    ---------------------------------------- 1.0/1.0 MB 239.3 kB/s eta 0:00:00
# Downloading langchain_core-0.3.69-py3-none-any.whl (441 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Downloading langsmith-0.4.8-py3-none-any.whl (367 kB)
# Downloading orjson-3.11.0-cp313-cp313-win_amd64.whl (129 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.23.0-cp313-cp313-win_amd64.whl (495 kB)
# Installing collected packages: zstandard, orjson, jsonpatch, requests-toolbelt, langsmith, langchain-core, langchain-text-splitters, langchain
#
#    ---------------------------------------- 0/8 [zstandard]
#    ---------- ----------------------------- 2/8 [jsonpatch]
#    --------------- ------------------------ 3/8 [requests-toolbelt]
#    --------------- ------------------------ 3/8 [requests-toolbelt]
#    --------------- ------------------------ 3/8 [requests-toolbelt]
#    --------------- ------------------------ 3/8 [requests-toolbelt]
#    --------------- ------------------------ 3/8 [requests-toolbelt]
#    --------------- ------------------------ 3/8 [requests-toolbelt]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    -------------------- ------------------- 4/8 [langsmith]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------- -------------- 5/8 [langchain-core]
#    ------------------------------ --------- 6/8 [langchain-text-splitters]
#    ------------------------------ --------- 6/8 [langchain-text-splitters]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ----------------------------------- ---- 7/8 [langchain]
#    ---------------------------------------- 8/8 [langchain]
#
# Successfully installed jsonpatch-1.33 langchain-0.3.26 langchain-core-0.3.69 langchain-text-splitters-0.3.8 langsmith-0.4.8 orjson-3.11.0 requests-toolbelt-1.0.0 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from plotly) (1.35.0)
# Requirement already satisfied: packaging in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from plotly) (24.2)
# Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 443.5 kB/s eta 0:00:21
#    -- ------------------------------------- 0.5/9.6 MB 443.5 kB/s eta 0:00:21
#    -- ------------------------------------- 0.5/9.6 MB 443.5 kB/s eta 0:00:21
#    -- ------------------------------------- 0.5/9.6 MB 443.5 kB/s eta 0:00:21
#    --- ------------------------------------ 0.8/9.6 MB 389.6 kB/s eta 0:00:23
#    --- ------------------------------------ 0.8/9.6 MB 389.6 kB/s eta 0:00:23
#    --- ------------------------------------ 0.8/9.6 MB 389.6 kB/s eta 0:00:23
#    --- ------------------------------------ 0.8/9.6 MB 389.6 kB/s eta 0:00:23
#    ---- ----------------------------------- 1.0/9.6 MB 343.6 kB/s eta 0:00:25
#    ---- ----------------------------------- 1.0/9.6 MB 343.6 kB/s eta 0:00:25
#    ---- ----------------------------------- 1.0/9.6 MB 343.6 kB/s eta 0:00:25
#    ---- ----------------------------------- 1.0/9.6 MB 343.6 kB/s eta 0:00:25
#    ---- ----------------------------------- 1.0/9.6 MB 343.6 kB/s eta 0:00:25
#    ---- ----------------------------------- 1.0/9.6 MB 343.6 kB/s eta 0:00:25
#    ----- ---------------------------------- 1.3/9.6 MB 292.6 kB/s eta 0:00:29
#    ----- ---------------------------------- 1.3/9.6 MB 292.6 kB/s eta 0:00:29
#    ----- ---------------------------------- 1.3/9.6 MB 292.6 kB/s eta 0:00:29
#    ----- ---------------------------------- 1.3/9.6 MB 292.6 kB/s eta 0:00:29
#    ----- ---------------------------------- 1.3/9.6 MB 292.6 kB/s eta 0:00:29
#    ----- ---------------------------------- 1.3/9.6 MB 292.6 kB/s eta 0:00:29
#    ------ --------------------------------- 1.6/9.6 MB 278.7 kB/s eta 0:00:29
#    ------ --------------------------------- 1.6/9.6 MB 278.7 kB/s eta 0:00:29
#    ------ --------------------------------- 1.6/9.6 MB 278.7 kB/s eta 0:00:29
#    ------ --------------------------------- 1.6/9.6 MB 278.7 kB/s eta 0:00:29
#    ------ --------------------------------- 1.6/9.6 MB 278.7 kB/s eta 0:00:29
#    ------- -------------------------------- 1.8/9.6 MB 272.9 kB/s eta 0:00:29
#    ------- -------------------------------- 1.8/9.6 MB 272.9 kB/s eta 0:00:29
#    ------- -------------------------------- 1.8/9.6 MB 272.9 kB/s eta 0:00:29
#    ------- -------------------------------- 1.8/9.6 MB 272.9 kB/s eta 0:00:29
#    ------- -------------------------------- 1.8/9.6 MB 272.9 kB/s eta 0:00:29
#    ------- -------------------------------- 1.8/9.6 MB 272.9 kB/s eta 0:00:29
#    ------- -------------------------------- 1.8/9.6 MB 272.9 kB/s eta 0:00:29
#    -------- ------------------------------- 2.1/9.6 MB 253.1 kB/s eta 0:00:30
#    -------- ------------------------------- 2.1/9.6 MB 253.1 kB/s eta 0:00:30
#    -------- ------------------------------- 2.1/9.6 MB 253.1 kB/s eta 0:00:30
#    -------- ------------------------------- 2.1/9.6 MB 253.1 kB/s eta 0:00:30
#    -------- ------------------------------- 2.1/9.6 MB 253.1 kB/s eta 0:00:30
#    -------- ------------------------------- 2.1/9.6 MB 253.1 kB/s eta 0:00:30
#    --------- ------------------------------ 2.4/9.6 MB 246.7 kB/s eta 0:00:30
#    --------- ------------------------------ 2.4/9.6 MB 246.7 kB/s eta 0:00:30
#    --------- ------------------------------ 2.4/9.6 MB 246.7 kB/s eta 0:00:30
#    --------- ------------------------------ 2.4/9.6 MB 246.7 kB/s eta 0:00:30
#    ---------- ----------------------------- 2.6/9.6 MB 252.6 kB/s eta 0:00:28
#    ---------- ----------------------------- 2.6/9.6 MB 252.6 kB/s eta 0:00:28
#    ---------- ----------------------------- 2.6/9.6 MB 252.6 kB/s eta 0:00:28
#    ----------- ---------------------------- 2.9/9.6 MB 260.9 kB/s eta 0:00:26
#    ----------- ---------------------------- 2.9/9.6 MB 260.9 kB/s eta 0:00:26
#    ----------- ---------------------------- 2.9/9.6 MB 260.9 kB/s eta 0:00:26
#    ----------- ---------------------------- 2.9/9.6 MB 260.9 kB/s eta 0:00:26
#    ------------- -------------------------- 3.1/9.6 MB 266.8 kB/s eta 0:00:25
#    ------------- -------------------------- 3.1/9.6 MB 266.8 kB/s eta 0:00:25
#    ------------- -------------------------- 3.1/9.6 MB 266.8 kB/s eta 0:00:25
#    -------------- ------------------------- 3.4/9.6 MB 273.8 kB/s eta 0:00:23
#    -------------- ------------------------- 3.4/9.6 MB 273.8 kB/s eta 0:00:23
#    --------------- ------------------------ 3.7/9.6 MB 286.2 kB/s eta 0:00:21
#    --------------- ------------------------ 3.7/9.6 MB 286.2 kB/s eta 0:00:21
#    ---------------- ----------------------- 3.9/9.6 MB 297.5 kB/s eta 0:00:20
#    ----------------- ---------------------- 4.2/9.6 MB 311.7 kB/s eta 0:00:18
#    ----------------- ---------------------- 4.2/9.6 MB 311.7 kB/s eta 0:00:18
#    ------------------ --------------------- 4.5/9.6 MB 323.9 kB/s eta 0:00:16
#    ------------------ --------------------- 4.5/9.6 MB 323.9 kB/s eta 0:00:16
#    ------------------- -------------------- 4.7/9.6 MB 333.5 kB/s eta 0:00:15
#    ------------------- -------------------- 4.7/9.6 MB 333.5 kB/s eta 0:00:15
#    -------------------- ------------------- 5.0/9.6 MB 342.6 kB/s eta 0:00:14
#    -------------------- ------------------- 5.0/9.6 MB 342.6 kB/s eta 0:00:14
#    --------------------- ------------------ 5.2/9.6 MB 351.3 kB/s eta 0:00:13
#    --------------------- ------------------ 5.2/9.6 MB 351.3 kB/s eta 0:00:13
#    ---------------------- ----------------- 5.5/9.6 MB 357.0 kB/s eta 0:00:12
#    ---------------------- ----------------- 5.5/9.6 MB 357.0 kB/s eta 0:00:12
#    ----------------------- ---------------- 5.8/9.6 MB 364.5 kB/s eta 0:00:11
#    ----------------------- ---------------- 5.8/9.6 MB 364.5 kB/s eta 0:00:11
#    ------------------------- -------------- 6.0/9.6 MB 370.0 kB/s eta 0:00:10
#    ------------------------- -------------- 6.0/9.6 MB 370.0 kB/s eta 0:00:10
#    ------------------------- -------------- 6.0/9.6 MB 370.0 kB/s eta 0:00:10
#    -------------------------- ------------- 6.3/9.6 MB 372.7 kB/s eta 0:00:09
#    --------------------------- ------------ 6.6/9.6 MB 383.6 kB/s eta 0:00:09
#    ---------------------------- ----------- 6.8/9.6 MB 394.2 kB/s eta 0:00:08
#    ---------------------------- ----------- 6.8/9.6 MB 394.2 kB/s eta 0:00:08
#    ----------------------------- ---------- 7.1/9.6 MB 400.3 kB/s eta 0:00:07
#    ----------------------------- ---------- 7.1/9.6 MB 400.3 kB/s eta 0:00:07
#    ------------------------------ --------- 7.3/9.6 MB 405.7 kB/s eta 0:00:06
#    ------------------------------ --------- 7.3/9.6 MB 405.7 kB/s eta 0:00:06
#    ------------------------------ --------- 7.3/9.6 MB 405.7 kB/s eta 0:00:06
#    ------------------------------- -------- 7.6/9.6 MB 409.4 kB/s eta 0:00:05
#    ------------------------------- -------- 7.6/9.6 MB 409.4 kB/s eta 0:00:05
#    -------------------------------- ------- 7.9/9.6 MB 413.6 kB/s eta 0:00:05
#    -------------------------------- ------- 7.9/9.6 MB 413.6 kB/s eta 0:00:05
#    --------------------------------- ------ 8.1/9.6 MB 416.9 kB/s eta 0:00:04
#    --------------------------------- ------ 8.1/9.6 MB 416.9 kB/s eta 0:00:04
#    ---------------------------------- ----- 8.4/9.6 MB 420.9 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.4/9.6 MB 420.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.7/9.6 MB 424.3 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.7/9.6 MB 424.3 kB/s eta 0:00:03
#    ----------------------------------- ---- 8.7/9.6 MB 424.3 kB/s eta 0:00:03
#    ------------------------------------- -- 8.9/9.6 MB 426.0 kB/s eta 0:00:02
#    ------------------------------------- -- 8.9/9.6 MB 426.0 kB/s eta 0:00:02
#    -------------------------------------- - 9.2/9.6 MB 430.0 kB/s eta 0:00:02
#    -------------------------------------- - 9.2/9.6 MB 430.0 kB/s eta 0:00:02
#    ---------------------------------------  9.4/9.6 MB 433.2 kB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 433.2 kB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 433.2 kB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 429.9 kB/s eta 0:00:00
# Installing collected packages: plotly
# Successfully installed plotly-6.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jinja2
# Out:
# Requirement already satisfied: jinja2 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sanju\appdata\local\programs\python\python313\lib\site-packages (from jinja2) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
# Note: you may need to restart the kernel to use updated packages.
